# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nba_games_2015_2022.csv', index_col = 0)

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  ...
# 1      240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# 2      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 3      240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 4      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 17765  240.0  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  ...
# 17766  240.0  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  ...
# 17767  240.0  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  ...
# 17768  240.0  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  ...
# 17769  240.0  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              57.1          33.8         258.0         121.0       ATL
# 1              33.3          23.6         132.0         104.0       DET
# 2              53.2          34.6         162.0         104.0       CHI
# 3              30.4          29.0         138.0         105.0       CLE
# 4              69.4          43.7         206.0         104.0       GSW
# ...             ...           ...           ...           ...       ...
# 17765          42.9          36.3         133.0         112.0       GSW
# 17766          33.3          36.2         222.0         107.0       GSW
# 17767          45.0          94.4         300.0         112.0       BOS
# 17768         100.0          42.6         141.0         126.0       BOS
# 17769          33.3          31.5         186.0         111.0       GSW
#
#        total_opp  home_opp  season        date    won
# 0             94         1    2016  2015-10-27   True
# 1            106         0    2016  2015-10-27  False
# 2             97         1    2016  2015-10-27  False
# 3             95         0    2016  2015-10-27   True
# 4            111         1    2016  2015-10-27  False
# ...          ...       ...     ...         ...    ...
# 17765        107         0    2022  2022-06-10  False
# 17766        104         1    2022  2022-06-13  False
# 17767         94         0    2022  2022-06-13   True
# 17768         90         1    2022  2022-06-16   True
# 17769        103         0    2022  2022-06-16  False
#
# [17770 rows x 150 columns]

# %%
df = df.sort_values('date')

# %%
df = df.reset_index(drop = True)

# %%
del df['mp.1']
del df['mp_opp.1']
del df['index_opp']

# %%
def add_target(group):
    group['target'] = group['won'].shift(-1)
    return group

df = df.groupby('team', group_keys = False).apply(add_target)

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  ...
# 1      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# 2      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 3      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 4      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17765  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17766  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17767  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17768  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
# 17769  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              33.8         258.0         121.0       ATL         94
# 1              23.6         132.0         104.0       DET        106
# 2              34.6         162.0         104.0       CHI         97
# 3              29.0         138.0         105.0       CLE         95
# 4              43.7         206.0         104.0       GSW        111
# ...             ...           ...           ...       ...        ...
# 17765          36.3         133.0         112.0       GSW        107
# 17766          36.2         222.0         107.0       GSW        104
# 17767          94.4         300.0         112.0       BOS         94
# 17768          42.6         141.0         126.0       BOS         90
# 17769          31.5         186.0         111.0       GSW        103
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27   True    True
# 1             0    2016  2015-10-27  False    True
# 2             1    2016  2015-10-27  False    True
# 3             0    2016  2015-10-27   True    True
# 4             1    2016  2015-10-27  False   False
# ...         ...     ...         ...    ...     ...
# 17765         0    2022  2022-06-10  False   False
# 17766         1    2022  2022-06-13  False   False
# 17767         0    2022  2022-06-13   True    True
# 17768         1    2022  2022-06-16   True     NaN
# 17769         0    2022  2022-06-16  False     NaN
#
# [17770 rows x 148 columns]

# %%
df[df['team'] == 'WAS']
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 8      240.0  33.0   84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  ...
# 50     240.0  35.0   68.0  0.515  12.0  21.0  0.571  36.0  44.0  0.818  ...
# 65     240.0  38.0   90.0  0.422   6.0  22.0  0.273  28.0  33.0  0.848  ...
# 119    240.0  42.0   87.0  0.483   8.0  23.0  0.348  10.0  14.0  0.714  ...
# 158    240.0  36.0   88.0  0.409   8.0  25.0  0.320  18.0  23.0  0.783  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17476  240.0  38.0   82.0  0.463   8.0  21.0  0.381  18.0  20.0  0.900  ...
# 17490  240.0  56.0  101.0  0.554  13.0  30.0  0.433   7.0  14.0  0.500  ...
# 17512  240.0  42.0   86.0  0.488  10.0  35.0  0.286   9.0  11.0  0.818  ...
# 17529  240.0  35.0   69.0  0.507   9.0  28.0  0.321  13.0  17.0  0.765  ...
# 17580  240.0  42.0   94.0  0.447   8.0  23.0  0.348  16.0  26.0  0.615  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 8              25.2         134.0          98.0       ORL         87
# 50             32.4         138.0         122.0       MIL        113
# 65             28.7         153.0         108.0       NYK        117
# 119            30.0         160.0         109.0       SAS         99
# 158            41.6         146.0         103.0       BOS        118
# ...             ...           ...           ...       ...        ...
# 17476          34.4         245.0         116.0       BOS        144
# 17490          32.8         168.0         132.0       MIN        114
# 17512          60.2         159.0         114.0       ATL        118
# 17529          35.5         135.0         104.0       NYK        114
# 17580          37.3         161.0         118.0       CHO        124
#
#        home_opp  season        date    won  target
# 8             1    2016  2015-10-28   True    True
# 50            1    2016  2015-10-30   True   False
# 65            0    2016  2015-10-31  False    True
# 119           0    2016  2015-11-04   True   False
# 158           1    2016  2015-11-06  False   False
# ...         ...     ...         ...    ...     ...
# 17476         1    2022  2022-04-03  False    True
# 17490         1    2022  2022-04-05   True   False
# 17512         1    2022  2022-04-06  False   False
# 17529         0    2022  2022-04-08  False   False
# 17580         1    2022  2022-04-10  False     NaN
#
# [580 rows x 148 columns]

# %%
df['target'][pd.isnull(df['target'])] = 2
df['target'] = df['target'].astype(int, errors = 'ignore')
# Out:
# C:\Users\Billy\AppData\Local\Temp\ipykernel_2752\1437349468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][pd.isnull(df['target'])] = 2

# %%
df['won'].value_counts()
# Out:
# True     8885
# False    8885
# Name: won, dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    8871
# 0    8869
# 2      30
# Name: target, dtype: int64

# %%
nulls = pd.isnull(df).sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  ...
# 1      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# 2      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 3      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 4      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17765  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17766  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17767  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17768  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
# 17769  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              33.8         258.0         121.0       ATL         94
# 1              23.6         132.0         104.0       DET        106
# 2              34.6         162.0         104.0       CHI         97
# 3              29.0         138.0         105.0       CLE         95
# 4              43.7         206.0         104.0       GSW        111
# ...             ...           ...           ...       ...        ...
# 17765          36.3         133.0         112.0       GSW        107
# 17766          36.2         222.0         107.0       GSW        104
# 17767          94.4         300.0         112.0       BOS         94
# 17768          42.6         141.0         126.0       BOS         90
# 17769          31.5         186.0         111.0       GSW        103
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27   True       1
# 1             0    2016  2015-10-27  False       1
# 2             1    2016  2015-10-27  False       1
# 3             0    2016  2015-10-27   True       1
# 4             1    2016  2015-10-27  False       0
# ...         ...     ...         ...    ...     ...
# 17765         0    2022  2022-06-10  False       0
# 17766         1    2022  2022-06-13  False       0
# 17767         0    2022  2022-06-13   True       1
# 17768         1    2022  2022-06-16   True       2
# 17769         0    2022  2022-06-16  False       2
#
# [17770 rows x 142 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha = 1)
split = TimeSeriesSplit(n_splits = 3)

sfs = SequentialFeatureSelector(rr, n_features_to_select = 50, direction = 'forward', cv = split)

# %%
removed_columns = ['season', 'date', 'won', 'target', 'team', 'team_opp']
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.409091  0.529412  0.277512  0.413793  0.378788  0.491686
# 1      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# 2      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# ...    ...       ...       ...       ...       ...       ...       ...
# 17765  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17766  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17767  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17768  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
# 17769  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.441860  0.396825  0.730455  ...      0.150193      0.800948
# 1      0.255814  0.222222  0.766628  ...      0.019255      0.203791
# 2      0.209302  0.253968  0.519253  ...      0.160462      0.345972
# 3      0.348837  0.349206  0.645274  ...      0.088575      0.232227
# 4      0.418605  0.412698  0.654609  ...      0.277279      0.554502
# ...         ...       ...       ...  ...           ...           ...
# 17765  0.302326  0.285714  0.693116  ...      0.182285      0.208531
# 17766  0.465116  0.476190  0.623104  ...      0.181001      0.630332
# 17767  0.279070  0.222222  0.844807  ...      0.928113      1.000000
# 17768  0.162791  0.111111  1.000000  ...      0.263158      0.246445
# 17769  0.232558  0.174603  0.903151  ...      0.120668      0.459716
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date    won  \
# 0          0.517647       ATL   0.288462       1.0    2016  2015-10-27   True
# 1          0.317647       DET   0.403846       0.0    2016  2015-10-27  False
# 2          0.317647       CHI   0.317308       1.0    2016  2015-10-27  False
# 3          0.329412       CLE   0.298077       0.0    2016  2015-10-27   True
# 4          0.317647       GSW   0.451923       1.0    2016  2015-10-27  False
# ...             ...       ...        ...       ...     ...         ...    ...
# 17765      0.411765       GSW   0.413462       0.0    2022  2022-06-10  False
# 17766      0.352941       GSW   0.384615       1.0    2022  2022-06-13  False
# 17767      0.411765       BOS   0.288462       0.0    2022  2022-06-13   True
# 17768      0.576471       BOS   0.250000       1.0    2022  2022-06-16   True
# 17769      0.400000       GSW   0.375000       0.0    2022  2022-06-16  False
#
#        target
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# ...       ...
# 17765       0
# 17766       0
# 17767       1
# 17768       2
# 17769       2
#
# [17770 rows x 142 columns]

# %%
sfs.fit(df[selected_columns], df['target'])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  'fg%',
#  '3p%',
#  'ft%',
#  'orb',
#  'pf',
#  'trb%',
#  'usg%',
#  'ft_max',
#  '+/-_max',
#  'efg%_max',
#  'drb%_max',
#  'tov%_max',
#  'usg%_max',
#  'drtg_max',
#  'mp_opp',
#  'fg_opp',
#  'blk_opp',
#  'trb%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'fg_max_opp',
#  'fga_max_opp',
#  'ft_max_opp',
#  'ft%_max_opp',
#  'stl_max_opp',
#  'blk_max_opp',
#  'pts_max_opp',
#  'drb%_max_opp',
#  'usg%_max_opp']

# %%
def backtest(data, model, predictors, start = 2, step = 1):
    all_predictions = []
    seasons = sorted(data['season'].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data['season'] < season]
        test = data[data['season'] == season]
        model.fit(train[predictors], train['target'])
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index = test.index)
        
        combined = pd.concat([test['target'], preds], axis = 1)
        combined.columns = ['actual', 'prediction']
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

predictions
# Out:
#        actual  prediction
# 5250        0           0
# 5251        1           0
# 5252        1           1
# 5253        1           0
# 5254        1           1
# ...       ...         ...
# 17765       0           0
# 17766       0           1
# 17767       1           0
# 17768       2           0
# 17769       2           1
#
# [12520 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions['actual'], predictions['prediction'])
# Out:
# 0.5460063897763578

# %%
df_rolling = df[list(selected_columns) + ['won', 'team', 'season']]

def find_team_averages(team):
    rolling = team.rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(['team', 'season'], group_keys = False).apply(find_team_averages)
# Out:
# C:\Users\Billy\AppData\Local\Temp\ipykernel_2752\1295257374.py:4: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['team'], dtype='object')
#   rolling = team.rolling(10).mean()

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17765  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17766  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17767  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17768  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
# 17769  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
#
#              ft       fta       ft%  ...  stl%_max_opp  blk%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17765  0.434884  0.373016  0.764177  ...        0.0570        0.1113
# 17766  0.434884  0.385714  0.736639  ...        0.0591        0.1113
# 17767  0.320930  0.282540  0.757993  ...        0.0716        0.1171
# 17768  0.316279  0.269841  0.801750  ...        0.0656        0.1152
# 17769  0.406977  0.357143  0.754142  ...        0.0572        0.1111
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  \
# 0               NaN           NaN           NaN           NaN        NaN
# 1               NaN           NaN           NaN           NaN        NaN
# 2               NaN           NaN           NaN           NaN        NaN
# 3               NaN           NaN           NaN           NaN        NaN
# 4               NaN           NaN           NaN           NaN        NaN
# ...             ...           ...           ...           ...        ...
# 17765      0.471908      0.170603      0.431754      0.522353   0.348077
# 17766      0.483229      0.174711      0.438863      0.483529   0.350000
# 17767      0.374109      0.321566      0.642654      0.564706   0.392308
# 17768      0.444025      0.308601      0.628910      0.568235   0.395192
# 17769      0.483229      0.172144      0.460190      0.472941   0.344231
#
#        home_opp  won  season
# 0           NaN  NaN     NaN
# 1           NaN  NaN     NaN
# 2           NaN  NaN     NaN
# 3           NaN  NaN     NaN
# 4           NaN  NaN     NaN
# ...         ...  ...     ...
# 17765       0.5  0.6  2022.0
# 17766       0.5  0.5  2022.0
# 17767       0.4  0.7  2022.0
# 17768       0.5  0.7  2022.0
# 17769       0.5  0.5  2022.0
#
# [17770 rows x 138 columns]

# %%
rolling_columns = [f'{col}_10' for col in df_rolling.columns]
df_rolling.columns = rolling_columns

df = pd.concat([df, df_rolling], axis = 1)

# %%
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 249    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 253    0.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 255    0.0  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 256    0.0  0.295455  0.235294  0.363636  0.344828  0.348485  0.439430
# ...    ...       ...       ...       ...       ...       ...       ...
# 17765  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17766  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17767  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17768  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
# 17769  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
#
#              ft       fta       ft%  ...  stl%_max_opp_10  blk%_max_opp_10  \
# 243    0.255814  0.238095  0.708285  ...           0.0628           0.0679
# 249    0.325581  0.238095  0.927655  ...           0.0613           0.0772
# 253    0.511628  0.412698  0.827305  ...           0.0699           0.1072
# 255    0.441860  0.396825  0.730455  ...           0.0657           0.1032
# 256    0.627907  0.476190  0.886814  ...           0.0747           0.0742
# ...         ...       ...       ...  ...              ...              ...
# 17765  0.302326  0.285714  0.693116  ...           0.0570           0.1113
# 17766  0.465116  0.476190  0.623104  ...           0.0591           0.1113
# 17767  0.279070  0.222222  0.844807  ...           0.0716           0.1171
# 17768  0.162791  0.111111  1.000000  ...           0.0656           0.1152
# 17769  0.232558  0.174603  0.903151  ...           0.0572           0.1111
#
#        tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  drtg_max_opp_10  \
# 243           0.413522         0.124134         0.361611         0.449412
# 249           0.469497         0.219641         0.394787         0.531765
# 253           0.380294         0.273427         0.270616         0.478824
# 255           0.437212         0.124904         0.404739         0.408235
# 256           0.303564         0.130552         0.387678         0.410588
# ...                ...              ...              ...              ...
# 17765         0.471908         0.170603         0.431754         0.522353
# 17766         0.483229         0.174711         0.438863         0.483529
# 17767         0.374109         0.321566         0.642654         0.564706
# 17768         0.444025         0.308601         0.628910         0.568235
# 17769         0.483229         0.172144         0.460190         0.472941
#
#        total_opp_10  home_opp_10  won_10  season_10
# 243        0.347115          0.4     0.8     2016.0
# 249        0.324038          0.5     1.0     2016.0
# 253        0.308654          0.6     0.7     2016.0
# 255        0.428846          0.2     0.3     2016.0
# 256        0.350962          0.5     0.5     2016.0
# ...             ...          ...     ...        ...
# 17765      0.348077          0.5     0.6     2022.0
# 17766      0.350000          0.5     0.5     2022.0
# 17767      0.392308          0.4     0.7     2022.0
# 17768      0.395192          0.5     0.7     2022.0
# 17769      0.344231          0.5     0.5     2022.0
#
# [15880 rows x 280 columns]

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby('team', group_keys = False).apply(lambda x: shift_col(x, col_name))

df['home_next'] = add_col(df, 'home')
df['team_opp_next'] = add_col(df, 'team_opp')
df['date_next'] = add_col(df, 'date')

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 249    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 253    0.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 255    0.0  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 256    0.0  0.295455  0.235294  0.363636  0.344828  0.348485  0.439430
# ...    ...       ...       ...       ...       ...       ...       ...
# 17765  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17766  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17767  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17768  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
# 17769  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
#
#              ft       fta       ft%  ...  usg%_max_opp_10  ortg_max_opp_10  \
# 243    0.255814  0.238095  0.708285  ...         0.124134         0.361611
# 249    0.325581  0.238095  0.927655  ...         0.219641         0.394787
# 253    0.511628  0.412698  0.827305  ...         0.273427         0.270616
# 255    0.441860  0.396825  0.730455  ...         0.124904         0.404739
# 256    0.627907  0.476190  0.886814  ...         0.130552         0.387678
# ...         ...       ...       ...  ...              ...              ...
# 17765  0.302326  0.285714  0.693116  ...         0.170603         0.431754
# 17766  0.465116  0.476190  0.623104  ...         0.174711         0.438863
# 17767  0.279070  0.222222  0.844807  ...         0.321566         0.642654
# 17768  0.162791  0.111111  1.000000  ...         0.308601         0.628910
# 17769  0.232558  0.174603  0.903151  ...         0.172144         0.460190
#
#        drtg_max_opp_10  total_opp_10  home_opp_10  won_10  season_10  \
# 243           0.449412      0.347115          0.4     0.8     2016.0
# 249           0.531765      0.324038          0.5     1.0     2016.0
# 253           0.478824      0.308654          0.6     0.7     2016.0
# 255           0.408235      0.428846          0.2     0.3     2016.0
# 256           0.410588      0.350962          0.5     0.5     2016.0
# ...                ...           ...          ...     ...        ...
# 17765         0.522353      0.348077          0.5     0.6     2022.0
# 17766         0.483529      0.350000          0.5     0.5     2022.0
# 17767         0.564706      0.392308          0.4     0.7     2022.0
# 17768         0.568235      0.395192          0.5     0.7     2022.0
# 17769         0.472941      0.344231          0.5     0.5     2022.0
#
#        home_next  team_opp_next   date_next
# 243          0.0            BOS  2015-11-13
# 249          1.0            BRK  2015-11-14
# 253          0.0            SAC  2015-11-15
# 255          1.0            TOR  2015-11-15
# 256          0.0            WAS  2015-11-14
# ...          ...            ...         ...
# 17765        0.0            GSW  2022-06-13
# 17766        1.0            GSW  2022-06-16
# 17767        0.0            BOS  2022-06-16
# 17768        NaN            NaN         NaN
# 17769        NaN            NaN         NaN
#
# [15880 rows x 283 columns]

# %%
full = df.merge(df[rolling_columns + ['team_opp_next', 'date_next', 'team']], left_on = ['team', 'date_next'], right_on = ['team_opp_next', 'date_next'])

# %%
full
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 1      0.0  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 2      0.0  0.340909  0.558824  0.186603  0.206897  0.469697  0.203088
# 3      0.0  0.431818  0.397059  0.401914  0.137931  0.212121  0.263658
# 4      0.0  0.318182  0.323529  0.318182  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 15767  0.0  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15768  0.0  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15769  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15770  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 15771  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
#
#              ft       fta       ft%  ...  tov%_max_opp_10_y  \
# 0      0.511628  0.412698  0.827305  ...           0.437212
# 1      0.441860  0.396825  0.730455  ...           0.380294
# 2      0.139535  0.111111  0.854142  ...           0.413732
# 3      0.418605  0.365079  0.757293  ...           0.468868
# 4      0.186047  0.158730  0.787631  ...           0.310377
# ...         ...       ...       ...  ...                ...
# 15767  0.372093  0.365079  0.659277  ...           0.457128
# 15768  0.255814  0.222222  0.766628  ...           0.471908
# 15769  0.302326  0.285714  0.693116  ...           0.431761
# 15770  0.465116  0.476190  0.623104  ...           0.374109
# 15771  0.279070  0.222222  0.844807  ...           0.483229
#
#        usg%_max_opp_10_y  ortg_max_opp_10_y  drtg_max_opp_10_y  \
# 0               0.124904           0.404739           0.408235
# 1               0.273427           0.270616           0.478824
# 2               0.156739           0.470142           0.391765
# 3               0.123107           0.332227           0.407059
# 4               0.127086           0.312796           0.410588
# ...                  ...                ...                ...
# 15767           0.235173           0.562085           0.552941
# 15768           0.170603           0.431754           0.522353
# 15769           0.242875           0.567773           0.575294
# 15770           0.321566           0.642654           0.564706
# 15771           0.174711           0.438863           0.483529
#
#        total_opp_10_y  home_opp_10_y  won_10_y  season_10_y  team_opp_next_y  \
# 0            0.428846            0.2       0.3       2016.0              TOR
# 1            0.308654            0.6       0.7       2016.0              SAC
# 2            0.436538            0.6       0.1       2016.0              DEN
# 3            0.370192            0.5       0.4       2016.0              ORL
# 4            0.353846            0.5       0.6       2016.0              PHI
# ...               ...            ...       ...          ...              ...
# 15767        0.429808            0.4       0.6       2022.0              BOS
# 15768        0.348077            0.5       0.6       2022.0              GSW
# 15769        0.394231            0.4       0.7       2022.0              BOS
# 15770        0.392308            0.4       0.7       2022.0              BOS
# 15771        0.350000            0.5       0.5       2022.0              GSW
#
#        team_y
# 0         SAC
# 1         TOR
# 2         NOP
# 3         MIN
# 4         DAL
# ...       ...
# 15767     GSW
# 15768     BOS
# 15769     GSW
# 15770     GSW
# 15771     BOS
#
# [15772 rows x 423 columns]

# %%
removed_columns = list(full.columns[full.dtypes == 'object']) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full['target'])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=50)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  'fg%',
#  '3p%',
#  'orb',
#  'tov',
#  'tov%',
#  'usg%',
#  'ortg',
#  'drb_max',
#  'trb%_max',
#  'mp_opp',
#  'ft_opp',
#  'pts_opp',
#  'usg%_opp',
#  'drtg_opp',
#  'fga_max_opp',
#  'ft%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'total_opp',
#  'orb_10_x',
#  'stl_10_x',
#  'usg%_10_x',
#  '+/-_max_10_x',
#  'ortg_max_10_x',
#  'drtg_max_10_x',
#  'ft_opp_10_x',
#  'ftr_opp_10_x',
#  'usg%_opp_10_x',
#  'drb_max_opp_10_x',
#  'ortg_max_opp_10_x',
#  'won_10_x',
#  'home_next',
#  'tov%_10_y',
#  'usg%_10_y',
#  'ft%_max_10_y',
#  'ts%_max_10_y',
#  'efg%_max_10_y',
#  'ast%_max_10_y',
#  'stl%_max_10_y',
#  'ft%_opp_10_y',
#  'blk_opp_10_y',
#  'pf_opp_10_y',
#  'usg%_opp_10_y',
#  'fg_max_opp_10_y',
#  'fga_max_opp_10_y',
#  'fg%_max_opp_10_y',
#  'ft%_max_opp_10_y',
#  'pf_max_opp_10_y',
#  'won_10_y']

# %%
predictions = backtest(full, rr, predictors)
accuracy_score(predictions['actual'], predictions['prediction'])
# Out:
# 0.6301036502929247
